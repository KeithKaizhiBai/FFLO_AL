# %% [markdown]
# The research focuses on a one-dimensional (1D) system with Rashba spin-orbital coupling (SOC) with internal d-wave altermagnetic order and s-wave superconducting pairing.

# %% [markdown]
# The model Hamiltonian of normal state reads
# $$
#     \mathcal{H}_0 = \sum_k \psi_k^\dagger h(k) \psi_k,
# $$
# where $\psi_k = (c_{k\uparrow}, c_{k\downarrow})^T$ is the electron annihilation operator, and $h(k)$ is a $2\times 2$ matrix in spin space, which can be expressed as
# $$
#     h(k) = \xi(k) + \bm{d}(k) \cdot \bm{\sigma}
# $$
# with
# $$
#     \xi(k) = t \cos k,~\bm{d}(k) = (0, \lambda_y \sin k, \lambda_z \sin k + J_A \cos k).
# $$
# Here, $t$ is the nearest-neighbor hopping amplitude, $\lambda_y$ and $\lambda_z$ are the strengths of Rashba SOC, and $J_A$ is the strength of d-wave altermagnetic order.
# The eigenvalues of $h(k)$ are given by
# $$
#     E_\pm(k) = \xi(k) \pm |\bm{d}(k)| = t \cos k \pm \sqrt{(\lambda_y^2 + \lambda_z^2) \sin^2 k + 2\lambda_z J_A \sin k \cos k + J_A^2 \cos^2 k},
# $$
# which correspond to the two spin-split bands.

# %% [markdown]
# When $J_A = 0$, the system owns a time-reversal symmetry $\mathcal{T} = i \sigma_y \mathcal{K}$, together with
# an inversion/mirror symmetry $\mathcal{M}_x = i\sigma_x$ with $k \rightarrow -k$.
#
# But when $J_A \neq 0$, both $\mathcal{T}$ and $\mathcal{M}_x$ are broken.

# %% [markdown]
# To generate pairing, we introduce on-site s-wave Hubbard interaction
# $$
#     \begin{aligned}
#         \mathcal{H}_I &= - U\sum_i n_{i\uparrow} n_{i\downarrow} \\
#         &= - \frac{U}{N} \sum_{k, k', q} c_{k+q/2, \uparrow}^\dagger c_{-k+q/2, \downarrow}^\dagger c_{-k'+q/2, \downarrow} c_{k' + q/2, \uparrow},
#     \end{aligned}
# $$
# and introduce the FFLO pairing order parameter
# $$
#     \Delta_q = \frac{U}{N} \sum_k \langle c_{-k+q/2, \downarrow} c_{k + q/2, \uparrow} \rangle,
# $$
# and assuming that the pairing order parameter is peaked near a certain $q$ while uniform in $k$,
# the interaction term can be decoupled as
# $$
#     \begin{aligned}
#         \mathcal{H}_I &\approx \sum_{k, q} -\left( \Delta_q c_{k+q/2, \uparrow}^\dagger c_{-k+q/2, \downarrow}^\dagger      +\text{h.c.} \right) + \frac{N}{U} |\Delta_q|^2.
#     \end{aligned}
# $$
# This is reasonable since the Bose-Einstein condensation of Cooper pairs forces all pairings to condense at the same momentum $q$, the one with the lowest free energy.
# Thus, by defining Nambu spinor
# $$
#     \Psi_k = (\psi_{k+q/2}, i\sigma_y\psi_{-k+q/2}^\dagger)^T = (c_{k+q/2, \uparrow}, c_{k+q/2, \downarrow}, c_{-k+q/2, \downarrow}^\dagger, -c_{-k+q/2, \uparrow}^\dagger)^T,
# $$
# the mean-field Hamiltonian can be written in the Bogoliubov-de Gennes (BdG) form as
# $$
#     \begin{aligned}
#         \mathcal{H}_{\text{BdG}} &= \frac{1}{2} \sum_k \Psi_k^\dagger H_{\text{BdG}}(k) \Psi_k + \frac{N}{U} |\Delta_q|^2,\\
#         H_{\text{BdG}}(k) &= \begin{pmatrix}
#             h(k+q/2) - \mu & \Delta_q \\
#             \Delta_q^* & -\sigma_y h^T(-k+q/2) \sigma_y + \mu
#         \end{pmatrix}\\
#         &= \begin{pmatrix}
#             \xi(k+q/2) + \bm{d}(k+q/2) \cdot \bm{\sigma} - \mu & \Delta_q \\
#             \Delta_q^* & -\xi(-k+q/2) + \bm{d}(-k+q/2) \cdot \bm{\sigma} + \mu
#         \end{pmatrix}\\
#         &= \begin{pmatrix}
#             \xi(k+q/2) + d_z(k+q/2) - \mu & -id_y(k+q/2) & \Delta_q & 0 \\
#             id_y(k+q/2) & \xi(k+q/2) - d_z(k+q/2) - \mu & 0 & \Delta_q \\
#             \Delta_q^* & 0 & -\xi(-k+q/2) + d_z(-k+q/2) + \mu & -id_y(-k+q/2) \\
#             0 & \Delta_q^* & id_y(-k+q/2) & -\xi(-k+q/2) - d_z(-k+q/2) + \mu
#         \end{pmatrix}.
#     \end{aligned}
# $$
# where $\mu$ is the chemical potential.

# %% [markdown]
# Basically, the FFLO transition can be determined by minimizing the free energy with respect to $\Delta_q$ and $q$. We thus need to write down the free energy density as
# $$
#     \begin{aligned}
#         \Omega(\Delta_q, q) &= \frac{1}{N} \braket{\mathcal{H}_{\text{BdG}}} \\
#         &= \frac{1}{2N} \sum_k \sum_{n=1}^4 E_n(k) f(E_n(k), T) + \frac{|\Delta_q|^2}{U},
#     \end{aligned}
# $$
# with $n$ being the band index, $E_n(k)$ being the eigenvalues of $H_{\text{BdG}}(k)$, and $f(E, T) = 1/(e^{E/k_B T} + 1)$ being the Fermi-Dirac distribution function.
# This energy functional can be minimized by scanning over a range of $\Delta_q$ and $q$ values, and finding the combination that yields the lowest free energy.
#
# Notice that in principle we should also solve the self-consistent gap equation
# $$
#     \begin{aligned}
#         \Delta_q &= \frac{U}{N} \sum_k \langle c_{-k+q/2, \downarrow} c_{k + q/2, \uparrow} \rangle\\
#         &= \frac{U}{N} \sum_k \sum_{n=1}^4 u_{n, k+q/2, \uparrow} v_{n, -k+q/2, \downarrow}^* f(E_n(k), T),
#     \end{aligned}
# $$
# where $u_{n, k+q/2, \uparrow}$ and $v_{n, -k+q/2, \downarrow}$ are the components of the eigenvector corresponding to $E_n(k)$ in the Nambu basis. In the form of BdG Hamiltonian, this means the eigenvector is of the form
# $$
#     \begin{pmatrix}
#         u_{n, k+q/2, \uparrow} \\
#         u_{n, k+q/2, \downarrow} \\
#         v_{n, -k+q/2, \downarrow}^* \\
#         -v_{n, -k+q/2, \uparrow}^*
#     \end{pmatrix}.
# $$
# This is equivalent to minimizing the free energy functional, since the gap equation is just the condition for the free energy to be at an extremum with respect to $\Delta_q$.

# %% [markdown]
# In real space, the BdG Hamiltonian can be written as
# $$
#     \begin{aligned}
#         \mathcal{H}_{\text{BdG}} &= \frac{1}{2} \sum_{i, j} \Psi_i^\dagger H_{\text{BdG}}(i, j) \Psi_j + \frac{N}{U} |\Delta_q|^2,\\
#         H_{\text{BdG}}(i, j) &= \begin{pmatrix}
#             h(i, j) - \mu \delta_{i, j} & \Delta_q \delta_{i, j} \\
#             \Delta_q^* \delta_{i, j} & -\sigma_y h^T(i, j) \sigma_y + \mu \delta_{i, j}
#         \end{pmatrix},
#     \end{aligned}
# $$
# where $h(i, j)$ is the Fourier transform of $h(k)$, and $\Psi_i$ is the Nambu spinor in real space defined as $\Psi_i = (c_{i, \uparrow}, c_{i, \downarrow}, c_{i, \downarrow}^\dagger, -c_{i, \uparrow}^\dagger)^T$.
# More explicitly in the big matrix form, we have
# $$
#     H_{\text{BdG}} = \begin{pmatrix}
#         h(1, 1) - \mu & h(1, 2) & \cdots & h(1, N) & \Delta_q & 0 & \cdots & 0 \\
#         h(2, 1) & h(2, 2) - \mu & \cdots & h(2, N) & 0 & \Delta_q & \cdots & 0 \\
#         \vdots & \vdots & \ddots & \vdots & \vdots & \vdots & \ddots & \vdots \\
#         h(N, 1) & h(N, 2) & \cdots & h(N, N) - \mu & 0 & 0 & \cdots & \Delta_q \\
#         \Delta_q^* & 0 & \cdots & 0 & -\sigma_y h^T(1, 1) \sigma_y + \mu & -\sigma_y h^T(1, 2) \sigma_y & \cdots & -\sigma_y h^T(1, N) \sigma_y \\
#         0 & \Delta_q^* & \cdots & 0 & -\sigma_y h^T(2, 1) \sigma_y & -\sigma_y h^T(2, 2) \sigma_y + \mu & \cdots & -\sigma_y h^T(2, N) \sigma_y \\
#         \vdots & \vdots & \ddots & \vdots & \vdots & \vdots & \ddots & \vdots \\
#         0 & 0 & \cdots & \Delta_q^* & -\sigma_y h^T(N, 1) \sigma_y & -\sigma_y h^T(N, 2) \sigma_y & \cdots & -\sigma_y h^T(N, N) \sigma_y + \mu
#     \end{pmatrix}.
# $$

# %%
import numpy as np 
import matplotlib.pyplot as plt
import time
from joblib import Parallel, delayed

# ------ Pauli matrices ------
sigma_0 = np.array([[1, 0], [0, 1]])
sigma_x = np.array([[0, 1], [1, 0]])
sigma_y = np.array([[0, -1j], [1j, 0]])
sigma_z = np.array([[1, 0], [0, -1]])
tau_0 = np.array([[1, 0], [0, 1]])
tau_x = np.array([[0, 1], [1, 0]])
tau_y = np.array([[0, -1j], [1j, 0]])
tau_z = np.array([[1, 0], [0, -1]])

# ------ Parameters ------
Delta_0 = 1.0 # energy unit
t = 1 * Delta_0
lambda_y = 0.6 * Delta_0
lambda_z = 0.6 * Delta_0
U = 1.6 * Delta_0
mu = 0.55
omega_D = 10
kT = 0.01 # in unit of Delta_0, temperature

# ------ alter-magnetic strength ------
JA_min = 0.4
JA_max = 1
n_JA = 100
JA_list = np.linspace(JA_min, JA_max, n_JA)

# ------ pairing & q-momentum ------
Delta_min = 0.0
Delta_max = 0.6
n_Delta = 100
Delta_list = np.linspace(Delta_min, Delta_max, n_Delta)

q_min = -0.8
q_max = 0
n_q = 100
q_list = np.linspace(q_min, q_max, n_q)

Omega_mat = np.zeros( (n_Delta, n_q) )

# ------ Initialization of Data ------
Delta_opt_list = np.zeros(n_JA)
q_opt_list = np.zeros(n_JA)
Omega_min_list = np.zeros(n_JA)
Z2_list = np.zeros(n_JA)

# ------ momentum space ------
N_k = 801
k_min = -np.pi
k_max = np.pi
dk = (k_max - k_min) / (N_k - 1)
k_max = k_max - dk
k_list = np.linspace(k_min, k_max, N_k - 1)

# ------ BdG Hamiltonian ------
def h_BdG(k, q, Delta, t, lambda_y, lambda_z, JA, mu):
    """ 
    4 by 4 BdG Hamiltonian
    """
    H = np.zeros((4, 4), dtype = complex)
    H[0, 0] = (t + JA) * np.cos(k + q / 2) + lambda_z * np.sin(k + q / 2) - mu
    H[0, 1] = -1j * lambda_y * np.sin(k + q / 2)
    H[1, 0] = 1j * lambda_y * np.sin(k + q / 2)
    H[1, 1] = (t - JA) * np.cos(k + q / 2) - lambda_z * np.sin(k + q / 2) - mu

    H[2, 2] = (- t + JA) * np.cos(-k + q / 2) + lambda_z * np.sin(-k + q / 2) + mu
    H[2, 3] = -1j * lambda_y * np.sin(-k + q / 2)
    H[3, 2] = 1j * lambda_y * np.sin(-k + q / 2)
    H[3, 3] = (- t - JA) * np.cos(-k + q / 2) - lambda_z * np.sin(-k + q / 2) + mu

    H[0, 2] = Delta
    H[1, 3] = Delta
    H[2, 0] = Delta
    H[3, 1] = Delta
    return (H + H.conj().T) / 2

def eig_normal(k, q, t, lambda_y, lambda_z, JA, mu):
    """
    Analytic eigenvalues of the normal state Hamiltonian (without pairing)
    """
    E1 = t * np.cos(k + q/2) + np.sqrt(JA ** 2 * np.cos(k + q/2) ** 2 + (lambda_y ** 2 + lambda_z ** 2) * np.sin(k + q/2) ** 2 + JA*lambda_z * np.sin(2*k + q)) - mu
    E2 = t * np.cos(k + q/2) - np.sqrt(JA ** 2 * np.cos(k + q/2) ** 2 + (lambda_y ** 2 + lambda_z ** 2) * np.sin(k + q/2) ** 2 + JA*lambda_z * np.sin(2*k + q)) - mu
    E3 = -t * np.cos(-k + q/2) + np.sqrt(JA ** 2 * np.cos(-k + q/2) ** 2 + (lambda_y ** 2 + lambda_z ** 2) * np.sin(-k + q/2) ** 2 - JA*lambda_z * np.sin(2*k - q)) + mu
    E4 = -t * np.cos(-k + q/2) - np.sqrt(JA ** 2 * np.cos(-k + q/2) ** 2 + (lambda_y ** 2 + lambda_z ** 2) * np.sin(-k + q/2) ** 2 - JA*lambda_z * np.sin(2*k - q)) + mu
    return np.array([E1, E2, E3, E4])

def fermi_dirac(E, kT):
    """ Fermi-Dirac distribution function """
    return 1 / (np.exp(E / kT) + 1)

# ------ Main loop ------
print('Starting the main loop...')
print('Scanning JA values...')
print(f'JA range: {JA_min} to {JA_max} with {n_JA} points')

def compute_single(i_JA):
    JA = JA_list[i_JA]

    for i_delta in range(n_Delta):
        Delta = Delta_list[i_delta]
        for i_q in range(n_q):
            q = q_list[i_q]

            F_BdG = 0
            F_normal = 0

            for k in k_list:
                H_BdG = h_BdG(k, q, Delta, t, lambda_y, lambda_z, JA, mu)
                E_BdG = np.linalg.eigvalsh(H_BdG).real
                # E_normal = eig_normal(k, q, t, lambda_y, lambda_z, JA, mu).real
                H_normal = h_BdG(k, q, 0, t, lambda_y, lambda_z, JA, mu)
                E_normal = np.linalg.eigvalsh(H_normal).real

                F_BdG += np.sum(E_BdG * fermi_dirac(E_BdG, kT))
                F_normal += np.sum(E_normal * fermi_dirac(E_normal, kT))

            Omega_mat[i_delta, i_q] = 0.5 * dk * (F_BdG - F_normal)/(2 * np.pi) + Delta**2 / U

    # Find the minimum Omega and corresponding Delta and q
    row, column = np.unravel_index(np.argmin(Omega_mat), Omega_mat.shape)
    delta_opt = Delta_list[row]
    q_opt = q_list[column]
    omega_opt = Omega_mat[row, column]

    Z2_opt = np.sign(
        (mu + t*np.cos(q_opt/2)**2 - (JA*np.cos(q_opt/2) + lambda_z * np.sin(q_opt/2))**2 + delta_opt**2 - lambda_y**2 * np.sin(q_opt/2)**2) *
        (mu - t*np.cos(q_opt/2)**2 - (JA*np.cos(q_opt/2) + lambda_z * np.sin(q_opt/2))**2 + delta_opt**2 - lambda_y**2 * np.sin(q_opt/2)**2)
    )

    return delta_opt, q_opt, omega_opt, Z2_opt

def process_results(n_JA):
    results = []
    start_time = time.time()
    completed_steps = 0

    generator = Parallel(n_jobs = 5, return_as = 'generator_unordered')(
        delayed(compute_single)(i_JA) for i_JA in range(n_JA)
    )

    for delta_opt, q_opt, omega_opt, Z2_opt in generator:
        results.append((delta_opt, q_opt, omega_opt, Z2_opt))
        completed_steps += 1
        elapsed_time = time.time() - start_time
        print(f'Completed {completed_steps}/{n_JA} JA values. Elapsed time: {elapsed_time:.2f} seconds.')

    return results

results = process_results(n_JA)
for i, (delta_opt, q_opt, omega_opt, Z2_opt) in enumerate(results):
    JA = JA_list[i]
    Delta_opt_list[i] = delta_opt
    q_opt_list[i] = q_opt
    Omega_min_list[i] = omega_opt
    Z2_list[i] = Z2_opt
# Out:
# Starting the main loop...
# Scanning JA values...
# JA range: 0.4 to 1 with 100 points
# Completed 1/100 JA values. Elapsed time: 1353.91 seconds.
# Completed 2/100 JA values. Elapsed time: 1354.35 seconds.
# Completed 3/100 JA values. Elapsed time: 1358.09 seconds.
# Completed 4/100 JA values. Elapsed time: 1359.11 seconds.
# Completed 5/100 JA values. Elapsed time: 1429.13 seconds.
# Completed 6/100 JA values. Elapsed time: 2656.16 seconds.
# Completed 7/100 JA values. Elapsed time: 2658.98 seconds.
# Completed 8/100 JA values. Elapsed time: 2666.96 seconds.
# Completed 9/100 JA values. Elapsed time: 2668.67 seconds.
# Completed 10/100 JA values. Elapsed time: 2809.40 seconds.
# Completed 11/100 JA values. Elapsed time: 3953.29 seconds.
# Completed 12/100 JA values. Elapsed time: 3959.02 seconds.
# Completed 13/100 JA values. Elapsed time: 3966.14 seconds.
# Completed 14/100 JA values. Elapsed time: 3969.11 seconds.
# Completed 15/100 JA values. Elapsed time: 4184.55 seconds.
# ...

# %%
# --- trial plot ---
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(JA_list, Delta_opt_list, marker='o')
plt.xlabel('JA')
plt.ylabel('Optimal Delta')
plt.title('Optimal Delta vs JA')
plt.subplot(2, 2, 2)
plt.plot(JA_list, q_opt_list, marker='o')
plt.xlabel('JA')
plt.ylabel('Optimal q')
plt.title('Optimal q vs JA')
plt.subplot(2, 2, 3)
plt.plot(JA_list, Omega_min_list, marker='o')
plt.xlabel('JA')
plt.ylabel('Minimum Omega')
plt.title('Minimum Omega vs JA')
plt.subplot(2, 2, 4)
plt.plot(JA_list, Z2_list, marker='o')
plt.xlabel('JA')
plt.ylabel('Z2 Invariant')
plt.title('Z2 Invariant vs JA')
plt.tight_layout()

# %%
# ------ Open boundary spectrum ------
# Notice that the pairing independent term does not dependent on Delta and q

Nx = 200

ens_open_list = np.zeros((n_JA, 4 * Nx))

# ------ JA-independent part of the normal state Hamiltonian ------
hop = np.diag(np.ones(Nx - 1), 1)
hxp = 0.5 * t * np.kron(tau_z, sigma_0) + - 0.5 * 1j * lambda_z * np.kron(tau_z, sigma_z) + 0.5 * 1j * lambda_y * np.kron(tau_z, sigma_y)
H_normal = np.kron(hop, hxp) + np.kron(hop.T, hxp.conj().T)

def compute_single(i_JA):
    JA = JA_list[i_JA]

    delta_opt = Delta_opt_list[i_JA]
    q_opt = q_opt_list[i_JA]

    hJA = 0.5 * JA * np.kron(tau_0, sigma_z)
    h_delta = delta_opt * np.cos(q_opt) * np.kron(tau_x, sigma_0) - delta_opt * np.sin(q_opt) * np.kron(tau_y, sigma_0) - mu * np.kron(tau_z, sigma_0)
    h_BdG = np.kron(hop, hJA) + np.kron(hop.T, hJA.conj().T) + np.kron(np.eye(Nx), h_delta) + H_normal
    E_BdG = np.linalg.eigvalsh(h_BdG).real
    return E_BdG

def process_results(n_JA):
    results = []
    start_time = time.time()
    completed_steps = 0

    generator = Parallel(n_jobs = 4, return_as = 'generator_unordered')(
        delayed(compute_single)(i_JA) for i_JA in range(n_JA)
    )

    for E_BdG in generator:
        results.append(E_BdG)
        completed_steps += 1
        elapsed_time = time.time() - start_time
        print(f'Completed {completed_steps}/{n_JA} JA values. Elapsed time: {elapsed_time:.2f} seconds.')

    return results
E_BdG_list = process_results(n_JA)
ens_open_list = np.array(E_BdG_list)
# Out:
# Completed 1/100 JA values. Elapsed time: 3.26 seconds.
# Completed 2/100 JA values. Elapsed time: 3.26 seconds.
# Completed 3/100 JA values. Elapsed time: 3.29 seconds.
# Completed 4/100 JA values. Elapsed time: 3.29 seconds.
# Completed 5/100 JA values. Elapsed time: 3.69 seconds.
# Completed 6/100 JA values. Elapsed time: 3.69 seconds.
# Completed 7/100 JA values. Elapsed time: 3.71 seconds.
# Completed 8/100 JA values. Elapsed time: 3.71 seconds.
# Completed 9/100 JA values. Elapsed time: 4.10 seconds.
# Completed 10/100 JA values. Elapsed time: 4.10 seconds.
# Completed 11/100 JA values. Elapsed time: 4.12 seconds.
# Completed 12/100 JA values. Elapsed time: 4.13 seconds.
# Completed 13/100 JA values. Elapsed time: 4.50 seconds.
# Completed 14/100 JA values. Elapsed time: 4.51 seconds.
# Completed 15/100 JA values. Elapsed time: 4.52 seconds.
# Completed 16/100 JA values. Elapsed time: 4.53 seconds.
# Completed 17/100 JA values. Elapsed time: 4.95 seconds.
# ...

# %%
# --- trial plot ---
# We want to plot the discrete spectrum as a function of JA, x-axis is JA, y-axis is energy, states in scatter points
plt.figure(figsize=(8, 6))
for i_JA in range(n_JA):
    JA = JA_list[i_JA]
    E_BdG = ens_open_list[i_JA]
    plt.scatter([JA] * len(E_BdG), E_BdG, s=10, color='blue')
plt.xlabel('JA')
plt.ylabel('Energy')
plt.ylim(-0.15, 0.15)
plt.title('Discrete Spectrum vs JA')
plt.show()

# %%
# Cursor can change this cell

from __future__ import annotations

import math
import json
import time
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, Literal, Tuple

import matplotlib.pyplot as plt
import numpy as np
import torch


@dataclass
class SimConfig:
    delta0: float = 1.0
    t: float = 1.0
    lambda_ry: float = 0.6
    lambda_rz: float = 0.6
    u: float = 1.6
    mu: float = 0.55
    omega_d: float = 10.0
    kt: float = 0.01
    var_min: float = 0.2
    var_max: float = 2.2
    n_var: int = 20
    delta_min: float = 0.0
    delta_max: float = 0.6
    q_min: float = -0.8
    q_max: float = 0.0
    n_delta: int = 20
    n_q: int = 20
    n_k: int = 20
    nx: int = 200
    ja_chunk: int = 4
    q_chunk: int = 200
    # k_chunk: int = 160
    k_chunk: int = 200
    obc_eig_device: Literal["cpu", "cuda"] = "cuda"
    obc_batch: bool = True
    linalg_library: Literal["default", "cusolver", "magma"] = "magma"
    dtype: torch.dtype = torch.float32

    def scaled(self) -> "SimConfig":
        scale = self.delta0
        return SimConfig(
            delta0=scale,
            t=self.t * scale,
            lambda_ry=self.lambda_ry * scale,
            lambda_rz=self.lambda_rz * scale,
            u=self.u * scale,
            mu=self.mu,
            omega_d=self.omega_d,
            kt=self.kt,
            var_min=self.var_min,
            var_max=self.var_max,
            n_var=self.n_var,
            delta_min=self.delta_min,
            delta_max=self.delta_max,
            q_min=self.q_min,
            q_max=self.q_max,
            n_delta=self.n_delta,
            n_q=self.n_q,
            n_k=self.n_k,
            nx=self.nx,
            ja_chunk=self.ja_chunk,
            q_chunk=self.q_chunk,
            k_chunk=self.k_chunk,
            obc_eig_device=self.obc_eig_device,
            obc_batch=self.obc_batch,
            linalg_library=self.linalg_library,
            dtype=self.dtype,
        )


class StageTimer:
    def __init__(self) -> None:
        self._t0: float | None = None
        self.stage_totals_s: Dict[str, float] = {}
        self.stage_counts: Dict[str, int] = {}

    def start(self) -> None:
        self._t0 = time.perf_counter()

    def stop_add(self, stage: str) -> None:
        if self._t0 is None:
            raise RuntimeError("Timer was not started.")
        dt = time.perf_counter() - self._t0
        self.stage_totals_s[stage] = self.stage_totals_s.get(stage, 0.0) + dt
        self.stage_counts[stage] = self.stage_counts.get(stage, 0) + 1
        self._t0 = None

    def add(self, stage: str, dt_s: float) -> None:
        self.stage_totals_s[stage] = self.stage_totals_s.get(stage, 0.0) + float(dt_s)
        self.stage_counts[stage] = self.stage_counts.get(stage, 0) + 1

    def summary_lines(self) -> list[str]:
        lines: list[str] = []
        for k in sorted(self.stage_totals_s.keys()):
            tot = self.stage_totals_s[k]
            cnt = self.stage_counts.get(k, 0)
            avg = tot / cnt if cnt else float("nan")
            lines.append(f"{k:>18s}: total={tot:9.3f}s  count={cnt:4d}  avg={avg:8.3f}s")
        return lines


def complex_dtype_for(real_dtype: torch.dtype) -> torch.dtype:
    if real_dtype == torch.float32:
        return torch.complex64
    if real_dtype == torch.float64:
        return torch.complex128
    raise TypeError(f"Unsupported dtype: {real_dtype}")


def require_cuda() -> torch.device:
    if not torch.cuda.is_available():
        raise RuntimeError("CUDA is required by this script but no GPU was detected.")
    return torch.device("cuda")

def synchronize_if_cuda(device: torch.device) -> None:
    if device.type == "cuda":
        torch.cuda.synchronize(device)

def build_k_grid(cfg: SimConfig, device: torch.device) -> torch.Tensor:
    return torch.linspace(-math.pi, math.pi, cfg.n_k, dtype=cfg.dtype, device=device)


def maybe_set_linalg_backend(cfg: SimConfig) -> None:
    if cfg.linalg_library == "default":
        return
    if torch.cuda.is_available():
        torch.backends.cuda.preferred_linalg_library(cfg.linalg_library)


def make_run_tag(cfg: SimConfig) -> str:
    dt = "fp32" if cfg.dtype == torch.float32 else "fp64" if cfg.dtype == torch.float64 else str(cfg.dtype).replace("torch.", "")
    obc = "obcGpu" if cfg.obc_eig_device == "cuda" else "obcCpu"
    obcb = "B1" if cfg.obc_batch else "B0"
    lib = f"lib{cfg.linalg_library}"
    return (
        f"nv{cfg.n_var}_nd{cfg.n_delta}_nq{cfg.n_q}_nk{cfg.n_k}_nx{cfg.nx}"
        f"_jc{cfg.ja_chunk}_qc{cfg.q_chunk}_kc{cfg.k_chunk}_{dt}_{obc}{obcb}_{lib}"
    )


def bdg_hamiltonian_batch(
    k: torch.Tensor,
    q: torch.Tensor,
    delta: torch.Tensor,
    t: float,
    lambda_ry: float,
    lambda_rz: float,
    ja: torch.Tensor | float,
    mu: torch.Tensor | float,
    complex_dtype: torch.dtype,
) -> torch.Tensor:
    ja_t = ja if isinstance(ja, torch.Tensor) else torch.as_tensor(ja, device=k.device, dtype=k.dtype)
    mu_t = mu if isinstance(mu, torch.Tensor) else torch.as_tensor(mu, device=k.device, dtype=k.dtype)
    k_b, q_b, delta_b, ja_b, mu_b = torch.broadcast_tensors(k, q, delta, ja_t, mu_t)
    kp = k_b + q_b / 2.0
    km = -k_b + q_b / 2.0

    h11 = (t + ja_b) * torch.cos(kp) + lambda_rz * torch.sin(kp) - mu_b
    h12 = -1j * lambda_ry * torch.sin(kp)
    h22 = (t - ja_b) * torch.cos(kp) - lambda_rz * torch.sin(kp) - mu_b

    h33 = -(t + ja_b) * torch.cos(km) - lambda_rz * torch.sin(km) + mu_b
    h34 = -1j * lambda_ry * torch.sin(km)
    h44 = -(t - ja_b) * torch.cos(km) + lambda_rz * torch.sin(km) + mu_b

    shape = k_b.shape + (4, 4)
    h = torch.zeros(shape, dtype=complex_dtype, device=k.device)
    h[..., 0, 0] = h11
    h[..., 0, 1] = h12
    h[..., 1, 0] = torch.conj(h12)
    h[..., 1, 1] = h22
    h[..., 2, 2] = h33
    h[..., 2, 3] = h34
    h[..., 3, 2] = torch.conj(h34)
    h[..., 3, 3] = h44

    h[..., 0, 3] = -delta_b
    h[..., 1, 2] = delta_b
    h[..., 2, 1] = delta_b
    h[..., 3, 0] = -delta_b
    return (h + torch.conj(h.transpose(-1, -2))) / 2.0

def fermi_weighted_sum(evals: torch.Tensor, kt: float) -> torch.Tensor:
    # Numerically stable form of E / (exp(E/kT) + 1).
    return torch.sum(evals * torch.sigmoid(-evals / kt), dim=-1)

def compute_omega_for_ja_batch(
    ja_vec: torch.Tensor,
    cfg: SimConfig,
    k_vec: torch.Tensor,
) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
    device = k_vec.device
    ctype = complex_dtype_for(cfg.dtype)
    delta_vec = torch.linspace(cfg.delta_min, cfg.delta_max, cfg.n_delta, dtype=cfg.dtype, device=device)
    q_vec = torch.linspace(cfg.q_min, cfg.q_max, cfg.n_q, dtype=cfg.dtype, device=device)

    mask = torch.abs(cfg.t * torch.cos(k_vec) - cfg.mu) < cfg.omega_d
    valid_k = k_vec[mask]
    if valid_k.numel() == 0:
        raise RuntimeError("No valid k-point satisfies Debye cutoff.")

    omega_mat = torch.empty((ja_vec.numel(), cfg.n_delta, cfg.n_q), dtype=cfg.dtype, device=device)
    delta_term = (delta_vec ** 2 / cfg.u).view(1, cfg.n_delta, 1)
    nk = float(cfg.n_k)

    for q_start in range(0, cfg.n_q, cfg.q_chunk):
        q_end = min(q_start + cfg.q_chunk, cfg.n_q)
        q_chunk = q_vec[q_start:q_end]

        d_b = delta_vec.view(1, cfg.n_delta, 1, 1)
        q_b = q_chunk.view(1, 1, q_chunk.numel(), 1)
        ja_b = ja_vec.view(ja_vec.numel(), 1, 1, 1)
        int_sum = torch.zeros((ja_vec.numel(), cfg.n_delta, q_chunk.numel()), dtype=cfg.dtype, device=device)
        int_sum0 = torch.zeros((ja_vec.numel(), cfg.n_delta, q_chunk.numel()), dtype=cfg.dtype, device=device)
        for k_start in range(0, valid_k.numel(), cfg.k_chunk):
            k_end = min(k_start + cfg.k_chunk, valid_k.numel())
            k_part = valid_k[k_start:k_end]
            k_b = k_part.view(1, 1, 1, k_part.numel())

            h = bdg_hamiltonian_batch(
                k=k_b,
                q=q_b,
                delta=d_b,
                t=cfg.t,
                lambda_ry=cfg.lambda_ry,
                lambda_rz=cfg.lambda_rz,
                ja=ja_b,
                mu=cfg.mu,
                complex_dtype=ctype,
            )
            evals = torch.linalg.eigvalsh(h).real
            int_sum += torch.sum(fermi_weighted_sum(evals, cfg.kt), dim=-1)

            h0 = bdg_hamiltonian_batch(
                k=k_b,
                q=q_b,
                delta=torch.zeros_like(d_b),
                t=cfg.t,
                lambda_ry=cfg.lambda_ry,
                lambda_rz=cfg.lambda_rz,
                ja=ja_b,
                mu=cfg.mu,
                complex_dtype=ctype,
            )
            evals0 = torch.linalg.eigvalsh(h0).real
            int_sum0 += torch.sum(fermi_weighted_sum(evals0, cfg.kt), dim=-1)

        omega_chunk = 0.5 * int_sum / nk + delta_term - 0.5 * int_sum0 / nk
        omega_mat[:, :, q_start:q_end] = omega_chunk

    return omega_mat, delta_vec, q_vec, valid_k


def compute_z2(cfg: SimConfig, ja: float, q_opt: float, delta_opt: float) -> float:
    lhs = (
        (cfg.mu + cfg.t * math.cos(q_opt / 2.0)) ** 2
        - (ja * math.cos(q_opt / 2.0) + cfg.lambda_rz * math.sin(q_opt / 2.0)) ** 2
        + delta_opt**2
        - (cfg.lambda_ry * math.sin(q_opt / 2.0)) ** 2
    )
    rhs = (
        (cfg.mu - cfg.t * math.cos(q_opt / 2.0)) ** 2
        - (ja * math.cos(q_opt / 2.0) + cfg.lambda_rz * math.sin(q_opt / 2.0)) ** 2
        + delta_opt**2
        - (cfg.lambda_ry * math.sin(q_opt / 2.0)) ** 2
    )
    return float(np.sign(lhs * rhs))


def build_obc_hamiltonian(cfg: SimConfig, ja: float, delta_opt: float, q_opt: float) -> np.ndarray:
    sigma_0 = np.eye(2, dtype=np.complex64)
    sigma_y = np.array([[0, -1j], [1j, 0]], dtype=np.complex64)
    sigma_z = np.array([[1, 0], [0, -1]], dtype=np.complex64)
    tau_0 = np.eye(2, dtype=np.complex64)
    tau_x = np.array([[0, 1], [1, 0]], dtype=np.complex64)
    tau_y = np.array([[0, -1j], [1j, 0]], dtype=np.complex64)
    tau_z = np.array([[1, 0], [0, -1]], dtype=np.complex64)

    n_states = 4 * cfg.nx
    h_const = np.zeros((n_states, n_states), dtype=np.complex64)

    hop = (
        0.5 * cfg.t * np.kron(tau_z, sigma_0)
        + 0.5 * ja * np.kron(tau_0, sigma_z)
        - 0.5j * cfg.lambda_rz * np.kron(tau_z, sigma_z)
        + 0.5j * cfg.lambda_ry * np.kron(tau_z, sigma_y)
    )
    for i in range(cfg.nx - 1):
        idx_i = slice(i * 4, (i + 1) * 4)
        idx_j = slice((i + 1) * 4, (i + 2) * 4)
        h_const[idx_i, idx_j] += hop
        h_const[idx_j, idx_i] += hop.conj().T

    for i in range(cfg.nx):
        delta_onsite = (
            delta_opt * math.cos(q_opt * (i + 1)) * np.kron(tau_x, sigma_0)
            - delta_opt * math.sin(q_opt * (i + 1)) * np.kron(tau_y, sigma_0)
        )
        idx = slice(i * 4, (i + 1) * 4)
        h_const[idx, idx] += delta_onsite

    h_mu = np.zeros((n_states, n_states), dtype=np.complex64)
    mu_term = -cfg.mu * np.kron(tau_z, sigma_0)
    for i in range(cfg.nx):
        idx = slice(i * 4, (i + 1) * 4)
        h_mu[idx, idx] += mu_term

    h = h_const + h_mu
    return (h + np.conj(h.T)) / 2.0


def bdg_hamiltonian_numpy(
    k: float,
    q: float,
    delta: float,
    t: float,
    lambda_ry: float,
    lambda_rz: float,
    ja: float,
    mu: float,
) -> np.ndarray:
    kp = k + q / 2.0
    km = -k + q / 2.0
    h11 = (t + ja) * math.cos(kp) + lambda_rz * math.sin(kp) - mu
    h12 = -1j * lambda_ry * math.sin(kp)
    h22 = (t - ja) * math.cos(kp) - lambda_rz * math.sin(kp) - mu
    h33 = -(t + ja) * math.cos(km) - lambda_rz * math.sin(km) + mu
    h34 = -1j * lambda_ry * math.sin(km)
    h44 = -(t - ja) * math.cos(km) + lambda_rz * math.sin(km) + mu
    h = np.zeros((4, 4), dtype=np.complex64)
    h[0, 0], h[0, 1], h[1, 0], h[1, 1] = h11, h12, np.conj(h12), h22
    h[2, 2], h[2, 3], h[3, 2], h[3, 3] = h33, h34, np.conj(h34), h44
    h[0, 3], h[1, 2], h[2, 1], h[3, 0] = -delta, delta, delta, -delta
    return (h + np.conj(h.T)) / 2.0


def plot_basic(
    cfg: SimConfig,
    var_vec: np.ndarray,
    delta_opt_vec: np.ndarray,
    q_opt_vec: np.ndarray,
    e_vals: np.ndarray,
    z2_vec: np.ndarray,
    out_dir: Path,
) -> None:
    fig = plt.figure(figsize=(12, 8))

    ax1 = fig.add_subplot(2, 2, 1)
    ax1.plot(var_vec, delta_opt_vec, "b-o", linewidth=2, markersize=6)
    ax1.set_xlabel("JA")
    ax1.set_ylabel(r"$\Delta_{opt}$")
    ax1.set_title("Optimal Pairing Gap vs Chemical Potential")
    ax1.grid(True)
    ax1.set_xlim(cfg.var_min, cfg.var_max)
    ax1.set_ylim(0, max(delta_opt_vec.max() * 1.1, 1e-6))

    ax2 = fig.add_subplot(2, 2, 2)
    ax2.plot(var_vec, q_opt_vec, "r-o", linewidth=2, markersize=6)
    ax2.set_xlabel("JA")
    ax2.set_ylabel(r"$q_{opt}$ (radians)")
    ax2.set_title("Optimal Center-of-Mass Momentum vs Chemical Potential")
    ax2.grid(True)
    ax2.set_xlim(cfg.var_min, cfg.var_max)

    ax3 = fig.add_subplot(2, 2, 3)
    for i in range(e_vals.shape[1]):
        ax3.plot(var_vec, e_vals[:, i], "bo", markersize=1.5)
    ax3.set_xlabel("JA")
    ax3.set_ylabel("E")
    ax3.set_title("spectrum vs Chemical Potential")
    ax3.grid(True)
    ax3.set_xlim(cfg.var_min, cfg.var_max)
    ax3.set_ylim(-0.1, 0.1)

    ax4 = fig.add_subplot(2, 2, 4)
    ax4.plot(var_vec, z2_vec, "m-o", linewidth=2, markersize=6)
    ax4.set_xlabel("JA")
    ax4.set_ylabel("Z2 Invariant")
    ax4.set_title("Topological Invariant vs Chemical Potential")
    ax4.grid(True)
    ax4.set_xlim(cfg.var_min, cfg.var_max)
    ax4.set_ylim(-1.5, 1.5)
    ax4.axhline(0, color="k", linestyle="--")
    ax4.axhline(1, color="r", linestyle="--")
    ax4.axhline(-1, color="b", linestyle="--")

    fig.tight_layout()
    fig.savefig(out_dir / "basic_results.png", dpi=200)
    fig.savefig(out_dir / "basic_results.pdf")
    plt.close(fig)


def plot_prl_style(
    cfg: SimConfig,
    var_vec: np.ndarray,
    delta_opt_vec: np.ndarray,
    q_opt_vec: np.ndarray,
    e_vals: np.ndarray,
    out_dir: Path,
) -> None:
    plt.rcParams.update(
        {
            "font.size": 9,
            "font.family": "DejaVu Sans",
        }
    )
    fig = plt.figure(figsize=(10, 6))
    var_samples = np.array([0.50, 0.593, 0.7], dtype=np.float32)
    cfflo_max = 0.593

    ax = fig.add_subplot(2, 2, 1)
    ax_r = ax.twinx()
    l1 = ax.plot(var_vec, delta_opt_vec, "b-o", linewidth=1.2, label=r"$\Delta_{opt}$")[0]
    l2 = ax_r.plot(var_vec, q_opt_vec, "r-s", linewidth=1.2, label=r"$q_{opt}$")[0]

    for s in var_samples:
        d_s = np.interp(s, var_vec, delta_opt_vec)
        q_s = np.interp(s, var_vec, q_opt_vec)
        ax.plot([s], [d_s], "ko", markersize=5)
        ax_r.plot([s], [q_s], "ko", markersize=5)
        ax.axvline(s, color="k", linestyle="--", linewidth=0.5)

    ax.set_xlabel(r"$J_A / t$", fontsize=14)
    ax.set_ylabel(r"$\Delta_{opt} / t$", color="b", fontsize=14)
    ax_r.set_ylabel(r"$q_{opt}$ (1/a)", color="r", fontsize=14)
    ax.set_xlim(cfg.var_min, cfg.var_max)
    ax.legend([l1, l2], [r"$\Delta_{opt}$", r"$q_{opt}$"], loc="upper right", frameon=False, fontsize=12)
    ax.grid(True, alpha=0.2)

    ax2 = fig.add_subplot(2, 2, 2)
    for i in range(e_vals.shape[1]):
        ax2.plot(var_vec, e_vals[:, i], ".", color=(0.6, 0.6, 0.6), markersize=2)

    min_abs = np.min(np.abs(e_vals), axis=1)
    tol = 0.005
    for idx, ja in enumerate(var_vec):
        if ja > cfflo_max:
            near_idx = np.where(np.abs(np.abs(e_vals[idx, :]) - min_abs[idx]) < tol)[0]
            for j in near_idx:
                ax2.plot(ja, e_vals[idx, j], "r.", markersize=8)

    y_fill = [-0.1, -0.1, 0.1, 0.1]
    ax2.fill([cfg.var_min, cfflo_max, cfflo_max, cfg.var_min], y_fill, color=(0.85, 0.95, 0.85), alpha=0.2, ec="none")
    ax2.fill([cfflo_max, cfg.var_max, cfg.var_max, cfflo_max], y_fill, color=(0.95, 0.85, 0.95), alpha=0.2, ec="none")
    ax2.axhline(0, color="k", linestyle="--", linewidth=0.5)
    ax2.axvline(cfflo_max, color="k", linewidth=0.8)
    ax2.text(cfg.var_min + 0.02, 0.085, "cFFLO", fontsize=12, color=(0, 0.5, 0), fontweight="bold")
    ax2.text(cfflo_max + 0.02, 0.085, "tFFLO", fontsize=12, color=(0.5, 0, 0.5), fontweight="bold")
    ax2.set_xlabel(r"$J_A / t$", fontsize=14)
    ax2.set_ylabel(r"$E / t$", fontsize=14)
    ax2.set_xlim(cfg.var_min, cfg.var_max)
    ax2.set_ylim(-0.15, 0.15)

    k_plot = np.linspace(-math.pi, math.pi, 500, dtype=np.float32)
    for i, s in enumerate(var_samples):
        idx = int(np.argmin(np.abs(var_vec - s)))
        d_s = float(delta_opt_vec[idx])
        q_s = float(q_opt_vec[idx])
        energies = np.zeros((k_plot.size, 4), dtype=np.float32)
        for ik, kval in enumerate(k_plot):
            ek = np.sort(np.real(np.linalg.eigvals(bdg_hamiltonian_numpy(kval, q_s, d_s, cfg.t, cfg.lambda_ry, cfg.lambda_rz, float(s), cfg.mu))))
            energies[ik, :] = ek

        axb = fig.add_subplot(2, 3, 4 + i)
        for b in range(4):
            axb.plot(k_plot, energies[:, b], "k-", linewidth=0.7)
        axb.axhline(0, color="k", linestyle="--", linewidth=0.5)
        if i == 0:
            axb.set_ylabel(r"$E / t$", fontsize=14)
        axb.set_xlabel("k (1/a)", fontsize=14)
        axb.set_title(f"J_A/t = {s:.2f}", fontsize=14)
        axb.text(0.05, 0.88, rf"$\Delta={d_s:.3f}$", transform=axb.transAxes, fontsize=10)
        axb.text(0.05, 0.80, f"q={q_s:.3f}", transform=axb.transAxes, fontsize=10)
        axb.set_xlim(-math.pi, math.pi)
        axb.set_ylim(-1.5, 1.5)
        axb.set_xticks([-math.pi, 0, math.pi])
        axb.set_xticklabels([r"$-\pi$", "0", r"$\pi$"])

    fig.subplots_adjust(left=0.07, right=0.98, top=0.96, bottom=0.08, wspace=0.35, hspace=0.35)
    fig.savefig(out_dir / "prl_combined_figure.png", dpi=250)
    fig.savefig(out_dir / "prl_combined_figure.pdf")
    plt.close(fig)


def run(cfg: SimConfig) -> Dict[str, np.ndarray]:
    cfg = cfg.scaled()
    device = require_cuda()
    maybe_set_linalg_backend(cfg)
    run_tag = make_run_tag(cfg)
    out_dir = Path.cwd() / "figures"
    out_dir.mkdir(exist_ok=True)

    var_vec = np.linspace(cfg.var_min, cfg.var_max, cfg.n_var, dtype=np.float32)
    delta_opt_vec = np.zeros(cfg.n_var, dtype=np.float32)
    q_opt_vec = np.zeros(cfg.n_var, dtype=np.float32)
    omega_min_vec = np.zeros(cfg.n_var, dtype=np.float32)
    z2_vec = np.zeros(cfg.n_var, dtype=np.float32)
    n_states = 4 * cfg.nx
    e_vals = np.zeros((cfg.n_var, n_states), dtype=np.float32)

    timer = StageTimer()
    t0 = time.perf_counter()
    k_vec = build_k_grid(cfg, device)
    synchronize_if_cuda(device)
    t1 = time.perf_counter()

    print("Scanning over JA...")
    print(f"JA range: [{cfg.var_min:.2f}, {cfg.var_max:.2f}]")
    print("Progress:")
    omega_elapsed = 0.0
    obc_elapsed = 0.0

    ja_all = torch.as_tensor(var_vec, device=device, dtype=cfg.dtype)
    delta_vec_t: torch.Tensor | None = None
    q_vec_t: torch.Tensor | None = None

    for ja_start in range(0, cfg.n_var, cfg.ja_chunk):
        ja_end = min(ja_start + cfg.ja_chunk, cfg.n_var)
        ja_part = ja_all[ja_start:ja_end]

        scan_start = time.perf_counter()
        omega_part, delta_vec_t, q_vec_t, _valid_k = compute_omega_for_ja_batch(ja_part, cfg, k_vec)
        synchronize_if_cuda(device)
        scan_end = time.perf_counter()
        dt = scan_end - scan_start
        omega_elapsed += dt
        timer.add("omega_ja_chunk", dt)

        omega_flat = omega_part.reshape(ja_part.numel(), -1)
        argmin = torch.argmin(omega_flat, dim=1)
        i_delta = (argmin // cfg.n_q).to(torch.int64)
        i_q = (argmin % cfg.n_q).to(torch.int64)

        delta_opt_part = delta_vec_t[i_delta].to("cpu", non_blocking=True).numpy()
        q_opt_part = q_vec_t[i_q].to("cpu", non_blocking=True).numpy()
        omega_min_part = omega_flat.gather(1, argmin[:, None]).squeeze(1).to("cpu", non_blocking=True).numpy()

        delta_opt_vec[ja_start:ja_end] = delta_opt_part.astype(np.float32)
        q_opt_vec[ja_start:ja_end] = q_opt_part.astype(np.float32)
        omega_min_vec[ja_start:ja_end] = omega_min_part.astype(np.float32)

        # Percentage-based progress output every 10%.
        if ja_start == 0:
            omega_next_pct = 10
            omega_loop_t0 = time.perf_counter()
        omega_done = ja_end
        omega_pct = int(100 * omega_done / cfg.n_var)
        while omega_pct >= omega_next_pct and omega_next_pct <= 100:
            elapsed = time.perf_counter() - omega_loop_t0
            eta = elapsed * (cfg.n_var - omega_done) / max(omega_done, 1)
            print(
                f"[Omega] {omega_next_pct:3d}% | done {omega_done}/{cfg.n_var} JA | "
                f"last_chunk {dt:.3f}s | elapsed {elapsed:.1f}s | ETA {eta:.1f}s"
            )
            omega_next_pct += 10

    if delta_vec_t is None or q_vec_t is None:
        raise RuntimeError("Internal error: delta/q grids were not initialized.")

    obc_use_cuda = cfg.obc_eig_device == "cuda"
    obc_device = device if obc_use_cuda else torch.device("cpu")
    obc_ctype = complex_dtype_for(torch.float32)

    for i, ja in enumerate(var_vec):
        z2_vec[i] = compute_z2(cfg, float(ja), float(q_opt_vec[i]), float(delta_opt_vec[i]))

    if obc_use_cuda and cfg.obc_batch:
        obc_stage_t0 = time.perf_counter()
        obc_start = time.perf_counter()
        h_stack = np.stack(
            [build_obc_hamiltonian(cfg, float(ja), float(delta_opt_vec[i]), float(q_opt_vec[i])) for i, ja in enumerate(var_vec)],
            axis=0,
        )
        timer.add("obc_build_stack", time.perf_counter() - obc_start)

        obc_start = time.perf_counter()
        h_t = torch.from_numpy(h_stack).to(device=obc_device, dtype=obc_ctype, non_blocking=True)
        ev = torch.linalg.eigvals(h_t).real.to("cpu", non_blocking=True).numpy()
        for i in range(cfg.n_var):
            e_vals[i, :] = np.sort(ev[i, :].astype(np.float32))
        synchronize_if_cuda(device)
        obc_end = time.perf_counter()
        obc_elapsed += obc_end - obc_start
        timer.add("obc_eig_batched", obc_end - obc_start)

        obc_stage_elapsed = time.perf_counter() - obc_stage_t0
        print(f"[OBC] 100% | batched mode | elapsed {obc_stage_elapsed:.1f}s")
        for i, ja in enumerate(var_vec):
            print(
                f"JA = {ja:.3f}: Delta_opt = {float(delta_opt_vec[i]):.4f}, q_opt = {float(q_opt_vec[i]):.4f}, Omega_min = {float(omega_min_vec[i]):.4f}"
            )
    else:
        obc_next_pct = 10
        obc_loop_t0 = time.perf_counter()
        for i, ja in enumerate(var_vec):
            delta_opt = float(delta_opt_vec[i])
            q_opt = float(q_opt_vec[i])
            min_omega = float(omega_min_vec[i])

            obc_start = time.perf_counter()
            h_total = build_obc_hamiltonian(cfg, float(ja), delta_opt, q_opt)
            timer.add("obc_build_one", time.perf_counter() - obc_start)

            obc_start = time.perf_counter()
            if obc_use_cuda:
                h_t = torch.from_numpy(h_total).to(device=obc_device, dtype=obc_ctype, non_blocking=True)
                ev = torch.linalg.eigvals(h_t).real.to("cpu", non_blocking=True).numpy()
            else:
                ev = np.real(np.linalg.eigvals(h_total))
            e_vals[i, :] = np.sort(ev.astype(np.float32))
            synchronize_if_cuda(device)
            obc_end = time.perf_counter()
            obc_elapsed += obc_end - obc_start
            timer.add("obc_eig_one", obc_end - obc_start)

            obc_done = i + 1
            obc_pct = int(100 * obc_done / cfg.n_var)
            while obc_pct >= obc_next_pct and obc_next_pct <= 100:
                elapsed = time.perf_counter() - obc_loop_t0
                eta = elapsed * (cfg.n_var - obc_done) / max(obc_done, 1)
                print(
                    f"[OBC]   {obc_next_pct:3d}% | done {obc_done}/{cfg.n_var} JA | "
                    f"last_eig {obc_end - obc_start:.3f}s | elapsed {elapsed:.1f}s | ETA {eta:.1f}s"
                )
                obc_next_pct += 10

            print(f"JA = {ja:.3f}: Delta_opt = {delta_opt:.4f}, q_opt = {q_opt:.4f}, Omega_min = {min_omega:.4f}")

    plot_start = time.perf_counter()
    plot_subdir = out_dir / run_tag
    plot_subdir.mkdir(exist_ok=True)
    plot_basic(cfg, var_vec, delta_opt_vec, q_opt_vec, e_vals, z2_vec, plot_subdir)
    plot_prl_style(cfg, var_vec, delta_opt_vec, q_opt_vec, e_vals, plot_subdir)
    plot_end = time.perf_counter()
    timer.add("plotting", plot_end - plot_start)

    print("\n=== Timing (seconds) ===")
    print(f"k-grid init: {t1 - t0:.3f}")
    print(f"Omega scan total: {omega_elapsed:.3f}")
    print(f"OBC spectrum total: {obc_elapsed:.3f}")
    print(f"Plotting total: {plot_end - plot_start:.3f}")
    print(f"All stages total: {plot_end - t0:.3f}")
    print("\n=== Stage timing details ===")
    for line in timer.summary_lines():
        print(line)

    timing_path = Path.cwd() / f"timing_{run_tag}.json"
    with timing_path.open("w", encoding="utf-8") as f:
        json.dump(
            {
                "run_tag": run_tag,
                "k_grid_init_s": float(t1 - t0),
                "omega_scan_total_s": float(omega_elapsed),
                "obc_total_s": float(obc_elapsed),
                "plotting_s": float(plot_end - plot_start),
                "all_total_s": float(plot_end - t0),
                "stage_totals_s": timer.stage_totals_s,
                "stage_counts": timer.stage_counts,
                "config": {
                    "n_var": cfg.n_var,
                    "n_delta": cfg.n_delta,
                    "n_q": cfg.n_q,
                    "n_k": cfg.n_k,
                    "nx": cfg.nx,
                    "ja_chunk": cfg.ja_chunk,
                    "q_chunk": cfg.q_chunk,
                    "k_chunk": cfg.k_chunk,
                    "dtype": str(cfg.dtype),
                    "obc_eig_device": cfg.obc_eig_device,
                    "obc_batch": cfg.obc_batch,
                    "linalg_library": cfg.linalg_library,
                    "var_min": cfg.var_min,
                    "var_max": cfg.var_max,
                    "mu": cfg.mu,
                    "u": cfg.u,
                    "omega_d": cfg.omega_d,
                    "kt": cfg.kt,
                },
            },
            f,
            indent=2,
            ensure_ascii=False,
        )

    return {
        "JA": var_vec,
        "Delta_opt_vec": delta_opt_vec,
        "q_opt_vec": q_opt_vec,
        "Omega_min_vec": omega_min_vec,
        "Z2_vec": z2_vec,
        "E_vals": e_vals,
    }


results = run(SimConfig())
# cfg = SimConfig().scaled()
# tag = make_run_tag(cfg)
# np.savez(Path.cwd() / f"results_tfflo_1d_cuda_{tag}.npz", **results)
# Out:
# Scanning over JA...
# JA range: [0.20, 2.20]
# Progress:
# [Omega]  10% | done 4/20 JA | last_chunk 0.420s | elapsed 0.0s | ETA 0.0s
# [Omega]  20% | done 4/20 JA | last_chunk 0.420s | elapsed 0.0s | ETA 0.0s
# [Omega]  30% | done 8/20 JA | last_chunk 0.111s | elapsed 0.1s | ETA 0.2s
# [Omega]  40% | done 8/20 JA | last_chunk 0.111s | elapsed 0.1s | ETA 0.2s
# [Omega]  50% | done 12/20 JA | last_chunk 0.096s | elapsed 0.2s | ETA 0.1s
# [Omega]  60% | done 12/20 JA | last_chunk 0.096s | elapsed 0.2s | ETA 0.1s
# [Omega]  70% | done 16/20 JA | last_chunk 0.110s | elapsed 0.3s | ETA 0.1s
# [Omega]  80% | done 16/20 JA | last_chunk 0.110s | elapsed 0.3s | ETA 0.1s
# [Omega]  90% | done 20/20 JA | last_chunk 0.111s | elapsed 0.4s | ETA 0.0s
# [Omega] 100% | done 20/20 JA | last_chunk 0.111s | elapsed 0.4s | ETA 0.0s
# [OBC] 100% | batched mode | elapsed 10.0s
# JA = 0.200: Delta_opt = 0.3789, q_opt = -0.0421, Omega_min = -0.0190
# ...

# %%
# Phase-diagram sweep over temperature kT (0 -> 0.1, 20 points)
# Keep original run() outputs/side-effects unchanged.

import numpy as np
import torch
from pathlib import Path

# Reuse definitions from previous cell:
# SimConfig, run

kT_values = np.linspace(0.0, 0.1, 20, dtype=np.float32)
all_results = {}

# q-phase-diagram data: rows -> kT, cols -> JA
JA_axis = None
q_phase_map = None

print(f"Starting kT sweep with {len(kT_values)} points...")

for i, kT_val in enumerate(kT_values, start=1):
    print("\n" + "=" * 80)
    print(f"[{i:02d}/{len(kT_values)}] Running kT = {kT_val:.5f}")

    cfg = SimConfig(
        kt=float(kT_val),
        # keep your current defaults/output behavior from tfflo_1d_cuda.py
        dtype=torch.float32,
    )

    results = run(cfg)
    all_results[float(kT_val)] = results

    # Initialize phase-map container using first run's JA axis.
    if JA_axis is None:
        JA_axis = results["JA"].copy()
        q_phase_map = np.zeros((len(kT_values), JA_axis.shape[0]), dtype=np.float32)

    q_phase_map[i - 1, :] = results["q_opt_vec"]

print("\nCompleted kT sweep.")
print("Stored in-memory results keys (kT):")
print(list(all_results.keys())[:5], "...", list(all_results.keys())[-5:])

# Export phase-diagram data for later plotting/analysis.
phase_data = {
    "kT_axis": kT_values,
    "JA_axis": JA_axis,
    "q_phase_map": q_phase_map,
}

fig_dir = Path.cwd() / "Data_Phase" / "phase_diagram_q_vs_kT_JA"
fig_dir.mkdir(parents=True, exist_ok=True)

np.savez(
    fig_dir / "phase_diagram_q_vs_kT_JA.npz",
    kT_axis=phase_data["kT_axis"],
    JA_axis=phase_data["JA_axis"],
    q_phase_map=phase_data["q_phase_map"],
)

print("Saved phase data -> Data_Phase/phase_diagram_q_vs_kT_JA/phase_diagram_q_vs_kT_JA.npz")
print(f"q_phase_map shape: {q_phase_map.shape}")
# Out:
# Starting kT sweep with 20 points...
#
# ...
# [01/20] Running kT = 0.00000
# Scanning over JA...
# JA range: [0.20, 2.20]
# Progress:
# [Omega]  10% | done 4/20 JA | last_chunk 0.156s | elapsed 0.0s | ETA 0.0s
# [Omega]  20% | done 4/20 JA | last_chunk 0.156s | elapsed 0.0s | ETA 0.0s
# [Omega]  30% | done 8/20 JA | last_chunk 0.137s | elapsed 0.1s | ETA 0.2s
# [Omega]  40% | done 8/20 JA | last_chunk 0.137s | elapsed 0.1s | ETA 0.2s
# [Omega]  50% | done 12/20 JA | last_chunk 0.117s | elapsed 0.3s | ETA 0.2s
# [Omega]  60% | done 12/20 JA | last_chunk 0.117s | elapsed 0.3s | ETA 0.2s
# [Omega]  70% | done 16/20 JA | last_chunk 0.141s | elapsed 0.4s | ETA 0.1s
# [Omega]  80% | done 16/20 JA | last_chunk 0.141s | elapsed 0.4s | ETA 0.1s
# [Omega]  90% | done 20/20 JA | last_chunk 0.167s | elapsed 0.6s | ETA 0.0s
# [Omega] 100% | done 20/20 JA | last_chunk 0.167s | elapsed 0.6s | ETA 0.0s
# [OBC] 100% | batched mode | elapsed 11.1s
# ...

# %%
# Plot q-phase diagram in (JA, kT) plane

import matplotlib.pyplot as plt
from pathlib import Path

if "phase_data" not in globals():
    raise RuntimeError("phase_data not found. Run the kT sweep cell first.")

kT_axis = phase_data["kT_axis"]
JA_axis = phase_data["JA_axis"]
q_map = phase_data["q_phase_map"]

fig, ax = plt.subplots(figsize=(8, 6))

im = ax.pcolormesh(
    JA_axis,
    kT_axis,
    q_map,
    shading="auto",
    cmap="coolwarm",
)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label(r"$q_{opt}$")

ax.set_xlabel(r"$J_A / t$")
ax.set_ylabel(r"$kT$")
ax.set_title(r"Phase Map of $q_{opt}$ in $(kT, J_A)$ plane")
ax.grid(alpha=0.15)

fig_dir = Path.cwd() / "Data_Phase" / "phase_diagram_q_vs_kT_JA"
fig_dir.mkdir(parents=True, exist_ok=True)

fig.tight_layout()
fig.savefig(fig_dir / "phase_diagram_q_vs_kT_JA.png", dpi=220)
fig.savefig(fig_dir / "phase_diagram_q_vs_kT_JA.pdf")
plt.show()

print("Saved figure -> Data_Phase/phase_diagram_q_vs_kT_JA/phase_diagram_q_vs_kT_JA.(png/pdf)")
# Out:
# Saved figure -> phase_diagram_q_vs_kT_JA.(png/pdf)

# %% [markdown]
# ### Eta 相图（从 `Data_Phase` 读取 npz）
#
# 运行 `eta_phase_diagram_cuda.py` 后，可用下方 cell 加载 `eta_phase_diagram_*.npz` 并用 **pcolormesh** 复现相图（与非均匀 `kT`/`J_A` 网格一致）。

# %%
# Load eta phase diagram from Data_Phase (matches non-uniform kT / JA grids via pcolormesh)
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import replace

from eta_phase_diagram_cuda import EtaPhaseConfig, bwr_cmap_adaptive, cell_edges_from_centers

# --- choose file: set explicit path, or use the latest run under Data_Phase ---
ETA_NPZ: Path | None = None  # e.g. Path("Data_Phase/eta_phase_diagram_.../eta_phase_diagram_....npz")

if ETA_NPZ is None:
    root = Path.cwd() / "Data_Phase"
    cands = sorted(
        root.glob("eta_phase_diagram_*/eta_phase_diagram_*.npz"),
        key=lambda p: p.stat().st_mtime,
        reverse=True,
    )
    if not cands:
        raise FileNotFoundError(
            "No eta_phase_diagram_*.npz found under Data_Phase/. Run eta_phase_diagram_cuda.py first or set ETA_NPZ."
        )
    ETA_NPZ = cands[0]

print("Using", ETA_NPZ.resolve())

d = np.load(ETA_NPZ, allow_pickle=True)
kT_vec = np.asarray(d["kT_vec"], dtype=np.float64)
JA_vec = np.asarray(d["JA_vec"], dtype=np.float64)
eta_matrix = np.asarray(d["eta_matrix"], dtype=np.float64)

delta0 = float(d["delta0"]) if "delta0" in d.files else float(EtaPhaseConfig().delta0)
cfg = replace(EtaPhaseConfig().scaled(), delta0=delta0)

kt_plot = kT_vec / cfg.delta0
ja_plot = JA_vec / cfg.delta0
kt_e = cell_edges_from_centers(kt_plot)
ja_e = cell_edges_from_centers(ja_plot)

min_eta = float(np.min(eta_matrix))
max_eta = float(np.max(eta_matrix))
if min_eta == 0 and max_eta == 0:
    min_eta, max_eta = -1e-6, 1e-6

cmap = plt.matplotlib.colors.ListedColormap(bwr_cmap_adaptive(min_eta, max_eta, 256))

fig, ax = plt.subplots(figsize=(8, 6))
mesh = ax.pcolormesh(
    kt_e,
    ja_e,
    eta_matrix,
    cmap=cmap,
    vmin=min_eta,
    vmax=max_eta,
    shading="flat",
)
fig.colorbar(mesh, ax=ax)
ax.set_xlabel(r"$k_B T / t$")
ax.set_ylabel(r"$J_A / t$")
ax.set_title("Superconducting Diode Effect Efficiency $\\eta$ Phase Diagram (from npz)")
ax.set_aspect("auto")

# Reference boundary (same as eta_phase_diagram_cuda.plot_eta_phase_diagram)
kt_boundary = np.array([0, 0.02, 0.04, 0.06, 0.08, 0.1, 0.13, 0.15, 0.2, 0.3, 0.4, 0.5, 0.55, 0.56], dtype=np.float32)
ja_boundary = np.array([2.12, 1.733, 1.5, 1.32, 1.16, 0.9, 0.78, 0.733, 0.7, 0.667, 0.59, 0.4, 0.178, 0], dtype=np.float32) * cfg.delta0
ax.plot(kt_boundary / cfg.delta0, ja_boundary / cfg.delta0, "k--", linewidth=2, label="Diode Region Boundary (eta=0 outside)")
ax.legend(loc="upper left", frameon=False, fontsize=10)

out_dir = ETA_NPZ.parent
stem = ETA_NPZ.stem
fig.tight_layout()
fig.savefig(out_dir / f"{stem}_notebook.png", dpi=220)
fig.savefig(out_dir / f"{stem}_notebook.pdf")
plt.show()
print(f"Saved -> {out_dir / (stem + '_notebook.png')}")
# Out:
# Using D:\PhD Study\4th\python\Fu_FFLO\Data_Phase\eta_phase_diagram_nkt46_nja52_nd200_nq200_nk400_kc4_jc4_qc40_kk80_fp64_libmagma\eta_phase_diagram_nkt46_nja52_nd200_nq200_nk400_kc4_jc4_qc40_kk80_fp64_libmagma.npz
# Saved -> d:\PhD Study\4th\python\Fu_FFLO\Data_Phase\eta_phase_diagram_nkt46_nja52_nd200_nq200_nk400_kc4_jc4_qc40_kk80_fp64_libmagma\eta_phase_diagram_nkt46_nja52_nd200_nq200_nk400_kc4_jc4_qc40_kk80_fp64_libmagma_notebook.png
